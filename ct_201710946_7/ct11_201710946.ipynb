# %% [markdown]
# <H1> 안녕 이건 큰 글씨야!!<H1>
# <H2> 안녕 이건 조금 큰 글씨야!!<H2>

# %% [markdown]
# # 큰 글씨
# ## 작은 글씨
# #### 더 작은 글씨

# %% [markdown]
# * 도시
#     * 서울
#     * 시드니
#     * 뉴욕
#         * 1번가
#         * 33번가

# %%
print ("Hello")
print ("1 + 2 =", 1 + 2)
# Out:
# Hello
# 1 + 2 = 3

# %%
from PIL import Image

# %%
m = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %%
m.show()

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(m)

# %% [markdown]
# * jpg파일을 gif파일로 변환하기
#     * 파일확장자를 gif로 적어준다.

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.gif")

# %%
mygif = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.gif")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(mygif)

# %% [markdown]
# * jpg파일을 png파일로 변환하기
#     * 파일확장자를 png로 적어준다.

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.png")

# %%
mypng = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.png")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(mypng)

# %% [markdown]
# * Operator overloading
#     * '*'가 숫자를 만나면

# %%
print(2 * 3)
# Out:
# 6

# %%
print("Hello " * 3)
# Out:
# Hello Hello Hello

# %% [markdown]
# * startswith() 기능 배우기

# %%
s = "Hello World"
s.startswith("H")
# Out:
# True

# %%
"Hello World".startswith("h")
# Out:
# False

# %%
type(s)
# Out:
# str

# %%
s1 = "123"
s2 = "111"
type(s1)
# Out:
# str

# %%
int(s1) + int(s2)
# Out:
# 234

# %%
s[0] == 'H'
# Out:
# True

# %%
msg = 'She says "Good Morning"'
print(msg)
# Out:
# She says "Good Morning"

# %%
s.endswith("d")
# Out:
# True

# %%
len(s)
# Out:
# 11

# %%
for ch in s :
    print (ch,)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in range(0,  11) :
    print(s[i],)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in range(0, len(s)) :
    print(s[i],)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
s.index("Wor")
# Out:
# 6

# %%
s.strip("rld")
# Out:
# 'Hello Wo'

# %%
s1 = "Hellow\nworld"
print(s1)
# Out:
# Hellow
# world

# %%
s1 = "Hello\n\tworld\n"
print(s1)
# Out:
# Hello
# 	world

# %%
print(s1.strip())
# Out:
# Hello
# 	world

# %%
print(s[-1])
# Out:
# d

# %%
print(s[0:-1])
# Out:
# Hello Worl

# %%
print(s[:])
# Out:
# Hello World
